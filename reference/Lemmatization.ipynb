# %% [markdown]
# ## Lemmatisation and Stemming
#
#  Lemmatisation and Stemming are two distinct word techniques which both search to extract base common parts of words. Both techniques generally require linguistic rules.
#
# #Lemmatisation
# Lemmatisation attempts to reduce tokens to a word that belongs in the language. The basic form of the word is called a lemma, and is the canonical form of a set of words. For example, *runs, running, ran* are all forms of the word *run*.
#
# #Stemming
# In the case of stemming, we want to normalise all words to their stem (or root). The stem is the part of the word to which affixes (suffixes or prefixes) are attached. Stemming a word may result in the word not actually looking like a word. For example, some stemming algorithms may stem *trouble, troubling, troubled* as *troubl*.

# %%
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet
from nltk import pos_tag

# Download required resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Helper to convert POS tags to WordNet format
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

sentence = 'The patient is a pleasant 57-year-old gentleman with worsening cardiomyopathy.'

# Tokenise and POS tag
tokens = word_tokenize(sentence)
tagged = pos_tag(tokens)

print(f"{'Word':<15}{'POS':<10}{'Stemmed':<15}{'Lemmatized':<15}")
print("-" * 55)
for word, pos in tagged:
    stemmed = stemmer.stem(word)
    wn_pos = get_wordnet_pos(pos)
    lemmatized = lemmatizer.lemmatize(word, wn_pos)
    print(f"{word:<15}{pos:<10}{stemmed:<15}{lemmatized:<15}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# Word           POS       Stemmed        Lemmatized
# -------------------------------------------------------
# The            DT        the            The
# patient        NN        patient        patient
# is             VBZ       is             be
# a              DT        a              a
# pleasant       JJ        pleasant       pleasant
# 57-year-old    JJ        57-year-old    57-year-old
# gentleman      NN        gentleman      gentleman
# with           IN        with           with
# worsening      VBG       worsen         worsen
# cardiomyopathy NN        cardiomyopathi cardiomyopathy
# .              .         .              .
